# %% [markdown]
# # Fine-tuning controlado de RoBERTa (GT vs Consenso LLM)

# %% [markdown]
# ## 1) Imports e setup

# %%
import pandas as pd
from transformers import TrainingArguments
from datasets import Dataset
from pathlib import Path

import sys
from loguru import logger
import pandas as pd

logger.remove()
logger.add(
    sys.stdout,
    format="<green>{time:HH:mm:ss}</green> | <level>{level: <8}</level> | <level>{message}</level>",
    level="INFO"
)

logger.success("✓ Setup completo")

# loaders
from src.utils.data_loader import load_hf_dataset_as_dataframe

# fine-tuning system
from src.fine_tune_system.fine_tune.supervised_fine_tuner import SupervisedFineTuner
from src.fine_tune_system.core.hf_tokenizer import HFTokenizer
from src.fine_tune_system.core.model_factory import ModelFactory
from src.fine_tune_system.training.trainer_builder import TrainerBuilder
from src.fine_tune_system.training.metrics import MetricsComputer
from src.fine_tune_system.training.label_schema import LabelSchema
from src.utils.dataset_aligner import DatasetAligner
# Out:
# 14:03:01 | SUCCESS  | ✓ Setup completo

# %% [markdown]
# ## 2) Configuração do experimento

# %% [markdown]
# ### - Configurações de dataset

# %%
from src.api.schemas.dataset import DatasetConfig

DATASET_GLOBAL_CONFIG_TRAIN = DatasetConfig(
    split="train",
    combine_splits=[],
    sample_size=None,
    random_state=42,
)

DATASET_GLOBAL_CONFIG_EVAL = DatasetConfig(
    split="test",
    combine_splits=[],
    sample_size=5000,
    random_state=42,
)

# %% [markdown]
# ### - Configurações de cache

# %%
CACHE_ENABLED = True
CACHE_DIR = "C:\\Users\\gabri\\Documents\\GitHub\\llm-annotation\\data\\.cache"

# %% [markdown]
# ### - Resultados

# %%
RESULTS_DIR = "C:\\Users\\gabri\\Documents\\GitHub\\llm-annotation\\data\\results"

# %%
from src.utils.get_latest_results_date import get_latest_results_date

DATASET_NAME = "dblp"  
specific_date = "latest"

if specific_date == "latest":
    specific_date = get_latest_results_date(
        RESULTS_DIR,
        DATASET_NAME
    )
    
RESULTS_DIR = Path(RESULTS_DIR)
results_dataset_path = RESULTS_DIR.joinpath(DATASET_NAME, specific_date)

# %% [markdown]
# ## 3) Carregar Dados

# %% [markdown]
# ### - Carregando

# %%
df = pd.read_csv(results_dataset_path.joinpath("summary", "dataset_anotado_completo.csv"))

print(f"Anotado: {len(df)}")
# Out:
# Anotado: 37385

# %% [markdown]
# ### - Dataset ground_truth

# %%
df_gt_train = (
    df[["text_id", "text", "ground_truth"]]
    .rename(columns={"ground_truth": "label"})
)

# %%
# Quantas duplicatas existem
num_duplicadas = df_gt_train.duplicated(subset=["text_id"]).sum()
print(f"Duplicatas encontradas: {num_duplicadas}")

# Ver exemplos
duplicadas = df_gt_train[df_gt_train.duplicated(subset=["text_id"], keep=False)]
duplicadas.sort_values("text")
# Out:
# Duplicatas encontradas: 147
#                                 text_id  \
# 14273  89d7fdd5d29c1e7be1743f5f535405e7
# 14272  89d7fdd5d29c1e7be1743f5f535405e7
# 4235   89d7fdd5d29c1e7be1743f5f535405e7
# 4236   89d7fdd5d29c1e7be1743f5f535405e7
# 17670  f7bcd53bdbf4021684067e7a517eb7f5
# ...                                 ...
# 13644  da3ef6f9e35fcb0b8d8d1fc8709a607e
# 13785  da3ef6f9e35fcb0b8d8d1fc8709a607e
# 13786  da3ef6f9e35fcb0b8d8d1fc8709a607e
# 1857   b751f05d496b0d382be68d42624113e0
# 1856   b751f05d496b0d382be68d42624113e0
#
#                                                     text  label
# 14273  a faster and simpler fully dynamic transitive ...      9
# 14272  a faster and simpler fully dynamic transitive ...      9
# 4235   a faster and simpler fully dynamic transitive ...      9
# 4236   a faster and simpler fully dynamic transitive ...      9
# 17670  a global geometric approach for image clusteri...      0
# ...                                                  ...    ...
# 13644  towards personal mt: general design, dialogue ...      1
# 13785  towards personal mt: general design, dialogue ...      1
# 13786  towards personal mt: general design, dialogue ...      1
# 1857   two-hand gesture recognition using coupled swi...      0
# 1856   two-hand gesture recognition using coupled swi...      0
#
# [218 rows x 3 columns]

# %%
from src.utils.data_loader import add_label_description

df_gt_train = add_label_description(
    df_gt_train,
    dataset_name=DATASET_NAME
)

# %%
label_schema = LabelSchema.from_dataframe(df_gt_train)
print(label_schema.id2label)
# Out:
# {0: 'negative sentiment', 1: 'positive sentiment'}

# %%
df_gt_train
# Out:
#                                 text_id  \
# 0      6de239969386800ffdf0242777786c25
# 1      27a36737f5398d6716d230af108dfc0c
# 2      291c460bf5ce5ca42eb82c8946407e0b
# 3      f806339daa6d03eb17716fcec63e6946
# 4      b061becd1af422a7a06f840b8cb75072
# ...                                 ...
# 10657  63d4880669f1831d8e2e06e146a5d362
# 10658  b505ee0f7dcbe4a8ceabd5d81d95327d
# 10659  3cb36356e338ef8387506ab68c84d5d0
# 10660  db69ef73c623fc39a04e8cac58292439
# 10661  f03049887fcce98a8992d1faaefb931f
#
#                                                     text  label  \
# 0      a comprehensive and provocative film -- one th...      1
# 1      perhaps the grossest movie ever made . funny ,...      1
# 2      the overall effect is awe and affection -- and...      1
# 3      you have to pay attention to follow all the st...      1
# 4      the movie is genial but never inspired , and l...      0
# ...                                                  ...    ...
# 10657  it's a drawling , slobbering , lovable run-on ...      1
# 10658  if the message seems more facile than the earl...      1
# 10659  i approached the usher and said that if she ha...      0
# 10660  it's the unsettling images of a war-ravaged la...      1
# 10661  my thoughts were focused on the characters . t...      1
#
#         label_description
# 0      positive sentiment
# 1      positive sentiment
# 2      positive sentiment
# 3      positive sentiment
# 4      negative sentiment
# ...                   ...
# 10657  positive sentiment
# 10658  positive sentiment
# 10659  negative sentiment
# 10660  positive sentiment
# 10661  positive sentiment
#
# [10662 rows x 4 columns]

# %% [markdown]
# ### - Dataset anotado

# %%
df_annotations = (
    df[["text_id", "text", "resolved_annotation"]]
    .rename(columns={"resolved_annotation": "label"})
)

# %%
df_annotations = add_label_description(
    df_annotations,
    dataset_name=DATASET_NAME
)

# %%
df_annotations
# Out:
#                                 text_id  \
# 0      6de239969386800ffdf0242777786c25
# 1      27a36737f5398d6716d230af108dfc0c
# 2      291c460bf5ce5ca42eb82c8946407e0b
# 3      f806339daa6d03eb17716fcec63e6946
# 4      b061becd1af422a7a06f840b8cb75072
# ...                                 ...
# 10657  63d4880669f1831d8e2e06e146a5d362
# 10658  b505ee0f7dcbe4a8ceabd5d81d95327d
# 10659  3cb36356e338ef8387506ab68c84d5d0
# 10660  db69ef73c623fc39a04e8cac58292439
# 10661  f03049887fcce98a8992d1faaefb931f
#
#                                                     text  label  \
# 0      a comprehensive and provocative film -- one th...      1
# 1      perhaps the grossest movie ever made . funny ,...      0
# 2      the overall effect is awe and affection -- and...      1
# 3      you have to pay attention to follow all the st...      1
# 4      the movie is genial but never inspired , and l...      0
# ...                                                  ...    ...
# 10657  it's a drawling , slobbering , lovable run-on ...      1
# 10658  if the message seems more facile than the earl...      0
# 10659  i approached the usher and said that if she ha...      0
# 10660  it's the unsettling images of a war-ravaged la...      1
# 10661  my thoughts were focused on the characters . t...      1
#
#         label_description
# 0      positive sentiment
# 1      negative sentiment
# 2      positive sentiment
# 3      positive sentiment
# 4      negative sentiment
# ...                   ...
# 10657  positive sentiment
# 10658  negative sentiment
# 10659  negative sentiment
# 10660  positive sentiment
# 10661  positive sentiment
#
# [10662 rows x 4 columns]

# %% [markdown]
# ### - Removendo instancias problemáticas e invalidas

# %% [markdown]
# #### -> Invalidas

# %% [markdown]
# ##### Removendo do Ground-Truth

# %%
df_invalid_gt = df_gt_train.loc[
    df_gt_train["label"] == -1 
]

df_gt_train = df_gt_train[
        ~df_gt_train["text_id"].isin(df_invalid_gt["text_id"])
    ].reset_index(drop=True)

# %%
df_gt_train
# Out:
#                                 text_id  \
# 0      6de239969386800ffdf0242777786c25
# 1      27a36737f5398d6716d230af108dfc0c
# 2      291c460bf5ce5ca42eb82c8946407e0b
# 3      f806339daa6d03eb17716fcec63e6946
# 4      b061becd1af422a7a06f840b8cb75072
# ...                                 ...
# 10657  63d4880669f1831d8e2e06e146a5d362
# 10658  b505ee0f7dcbe4a8ceabd5d81d95327d
# 10659  3cb36356e338ef8387506ab68c84d5d0
# 10660  db69ef73c623fc39a04e8cac58292439
# 10661  f03049887fcce98a8992d1faaefb931f
#
#                                                     text  label  \
# 0      a comprehensive and provocative film -- one th...      1
# 1      perhaps the grossest movie ever made . funny ,...      1
# 2      the overall effect is awe and affection -- and...      1
# 3      you have to pay attention to follow all the st...      1
# 4      the movie is genial but never inspired , and l...      0
# ...                                                  ...    ...
# 10657  it's a drawling , slobbering , lovable run-on ...      1
# 10658  if the message seems more facile than the earl...      1
# 10659  i approached the usher and said that if she ha...      0
# 10660  it's the unsettling images of a war-ravaged la...      1
# 10661  my thoughts were focused on the characters . t...      1
#
#         label_description
# 0      positive sentiment
# 1      positive sentiment
# 2      positive sentiment
# 3      positive sentiment
# 4      negative sentiment
# ...                   ...
# 10657  positive sentiment
# 10658  positive sentiment
# 10659  negative sentiment
# 10660  positive sentiment
# 10661  positive sentiment
#
# [10662 rows x 4 columns]

# %% [markdown]
# ##### Removendo da anotação

# %%
df_invalid = df_annotations.loc[
    df_annotations["label"] == -1 
]

df_annotations = df_annotations[
        ~df_annotations["text_id"].isin(df_invalid["text_id"])
    ].reset_index(drop=True)

# %%
df_annotations
# Out:
#                                 text_id  \
# 0      6de239969386800ffdf0242777786c25
# 1      27a36737f5398d6716d230af108dfc0c
# 2      291c460bf5ce5ca42eb82c8946407e0b
# 3      f806339daa6d03eb17716fcec63e6946
# 4      b061becd1af422a7a06f840b8cb75072
# ...                                 ...
# 10648  63d4880669f1831d8e2e06e146a5d362
# 10649  b505ee0f7dcbe4a8ceabd5d81d95327d
# 10650  3cb36356e338ef8387506ab68c84d5d0
# 10651  db69ef73c623fc39a04e8cac58292439
# 10652  f03049887fcce98a8992d1faaefb931f
#
#                                                     text  label  \
# 0      a comprehensive and provocative film -- one th...      1
# 1      perhaps the grossest movie ever made . funny ,...      0
# 2      the overall effect is awe and affection -- and...      1
# 3      you have to pay attention to follow all the st...      1
# 4      the movie is genial but never inspired , and l...      0
# ...                                                  ...    ...
# 10648  it's a drawling , slobbering , lovable run-on ...      1
# 10649  if the message seems more facile than the earl...      0
# 10650  i approached the usher and said that if she ha...      0
# 10651  it's the unsettling images of a war-ravaged la...      1
# 10652  my thoughts were focused on the characters . t...      1
#
#         label_description
# 0      positive sentiment
# 1      negative sentiment
# 2      positive sentiment
# 3      positive sentiment
# 4      negative sentiment
# ...                   ...
# 10648  positive sentiment
# 10649  negative sentiment
# 10650  negative sentiment
# 10651  positive sentiment
# 10652  positive sentiment
#
# [10653 rows x 4 columns]

# %% [markdown]
# #### -> Problematicas

# %%
problematica_cases_path = results_dataset_path.joinpath("consensus", "problematic_cases.csv")
df_problematic = None

# %% [markdown]
# ##### Removendo do Ground-Truth

# %%
if problematica_cases_path.exists():
    df_problematic = pd.read_csv(problematica_cases_path)
    df_gt_train = df_gt_train[
        ~df_gt_train["text_id"].isin(df_problematic["text_id"])
    ].reset_index(drop=True)

# %%
df_gt_train
# Out:
#                                 text_id  \
# 0      6de239969386800ffdf0242777786c25
# 1      27a36737f5398d6716d230af108dfc0c
# 2      291c460bf5ce5ca42eb82c8946407e0b
# 3      f806339daa6d03eb17716fcec63e6946
# 4      b061becd1af422a7a06f840b8cb75072
# ...                                 ...
# 10649  63d4880669f1831d8e2e06e146a5d362
# 10650  b505ee0f7dcbe4a8ceabd5d81d95327d
# 10651  3cb36356e338ef8387506ab68c84d5d0
# 10652  db69ef73c623fc39a04e8cac58292439
# 10653  f03049887fcce98a8992d1faaefb931f
#
#                                                     text  label  \
# 0      a comprehensive and provocative film -- one th...      1
# 1      perhaps the grossest movie ever made . funny ,...      1
# 2      the overall effect is awe and affection -- and...      1
# 3      you have to pay attention to follow all the st...      1
# 4      the movie is genial but never inspired , and l...      0
# ...                                                  ...    ...
# 10649  it's a drawling , slobbering , lovable run-on ...      1
# 10650  if the message seems more facile than the earl...      1
# 10651  i approached the usher and said that if she ha...      0
# 10652  it's the unsettling images of a war-ravaged la...      1
# 10653  my thoughts were focused on the characters . t...      1
#
#         label_description
# 0      positive sentiment
# 1      positive sentiment
# 2      positive sentiment
# 3      positive sentiment
# 4      negative sentiment
# ...                   ...
# 10649  positive sentiment
# 10650  positive sentiment
# 10651  negative sentiment
# 10652  positive sentiment
# 10653  positive sentiment
#
# [10654 rows x 4 columns]

# %% [markdown]
# ##### Removendo da anotação

# %%
if problematica_cases_path.exists():
    df_problematic = pd.read_csv(problematica_cases_path)
    df_annotations = df_annotations[
        ~df_annotations["text_id"].isin(df_problematic["text_id"])
    ].reset_index(drop=True)

# %%
df_annotations
# Out:
#                                 text_id  \
# 0      6de239969386800ffdf0242777786c25
# 1      27a36737f5398d6716d230af108dfc0c
# 2      291c460bf5ce5ca42eb82c8946407e0b
# 3      f806339daa6d03eb17716fcec63e6946
# 4      b061becd1af422a7a06f840b8cb75072
# ...                                 ...
# 10648  63d4880669f1831d8e2e06e146a5d362
# 10649  b505ee0f7dcbe4a8ceabd5d81d95327d
# 10650  3cb36356e338ef8387506ab68c84d5d0
# 10651  db69ef73c623fc39a04e8cac58292439
# 10652  f03049887fcce98a8992d1faaefb931f
#
#                                                     text  label  \
# 0      a comprehensive and provocative film -- one th...      1
# 1      perhaps the grossest movie ever made . funny ,...      0
# 2      the overall effect is awe and affection -- and...      1
# 3      you have to pay attention to follow all the st...      1
# 4      the movie is genial but never inspired , and l...      0
# ...                                                  ...    ...
# 10648  it's a drawling , slobbering , lovable run-on ...      1
# 10649  if the message seems more facile than the earl...      0
# 10650  i approached the usher and said that if she ha...      0
# 10651  it's the unsettling images of a war-ravaged la...      1
# 10652  my thoughts were focused on the characters . t...      1
#
#         label_description
# 0      positive sentiment
# 1      negative sentiment
# 2      positive sentiment
# 3      positive sentiment
# 4      negative sentiment
# ...                   ...
# 10648  positive sentiment
# 10649  negative sentiment
# 10650  negative sentiment
# 10651  positive sentiment
# 10652  positive sentiment
#
# [10653 rows x 4 columns]

# %% [markdown]
# ### - Carrega dataset de teste e validação

# %%
df_eval, _ = load_hf_dataset_as_dataframe(
    dataset_name=DATASET_NAME,
    cache_dir=CACHE_DIR,
    dataset_global_config=DATASET_GLOBAL_CONFIG_EVAL,
)

print(f"Avaliação HF: {len(df_eval)}")
# Out:
# 12:34:24 | INFO     | Carregando dataset: movie_review
# 12:34:30 | INFO     | Split 'test': 10662 exemplos
# 12:34:30 | INFO     | Categorias extraídas automaticamente: [0, 1]
# 12:34:30 | INFO     | Dataset embaralhado com seed=42
# 12:34:30 | INFO     | Amostra reduzida para 5000 exemplos
# 12:34:30 | INFO     | Coluna de texto: text
# 12:34:30 | INFO     | Ground truth carregado da coluna 'label'
# 12:34:30 | INFO     | DataFrame criado com 5000 linhas
# Avaliação HF: 5000

# %%
from sklearn.model_selection import train_test_split

df_gt_val, df_gt_test = train_test_split(
    df_eval,
    test_size=0.5,
    random_state=42,
    stratify=df_eval["label"]
)

# %%
df_gt_val
# Out:
#                                                    text  label  \
# 55    queen of the damned is too long with too littl...      0
# 1128  nonchalantly freaky and uncommonly pleasurable...      1
# 900   its over-reliance on genre conventions , chara...      0
# 588   a mix of velocity and idiocy , this ruinous re...      0
# 4174  the logic of it all will be greek to anyone no...      0
# ...                                                 ...    ...
# 3164  a fine , rousing , g-rated family film , aimed...      1
# 3027  beneath the film's obvious determination to sh...      1
# 1410  would be an unendurable viewing experience for...      1
# 495   it is a strength of a documentary to disregard...      1
# 4722  it would work much better as a one-hour tv doc...      0
#
#        label_description
# 55    negative sentiment
# 1128  positive sentiment
# 900   negative sentiment
# 588   negative sentiment
# 4174  negative sentiment
# ...                  ...
# 3164  positive sentiment
# 3027  positive sentiment
# 1410  positive sentiment
# 495   positive sentiment
# 4722  negative sentiment
#
# [2500 rows x 3 columns]

# %%
df_gt_test
# Out:
#                                                    text  label  \
# 44    the script manages the rare trick of seeming a...      1
# 3092  the script becomes lifeless and falls apart li...      0
# 1915  [barry] gives assassin a disquieting authority...      1
# 2332  the level of acting elevates the material abov...      1
# 2263  neil burger here succeeded in . . . making the...      1
# ...                                                 ...    ...
# 4207  a clash between the artificial structure of th...      0
# 813   the message of such reflections--intentional o...      1
# 1248  a sequel that's much too big for its britches .\n      0
# 673   a combination of standard , stiff tv-style ani...      0
# 2657                shallow , noisy and pretentious .\n      0
#
#        label_description
# 44    positive sentiment
# 3092  negative sentiment
# 1915  positive sentiment
# 2332  positive sentiment
# 2263  positive sentiment
# ...                  ...
# 4207  negative sentiment
# 813   positive sentiment
# 1248  negative sentiment
# 673   negative sentiment
# 2657  negative sentiment
#
# [2500 rows x 3 columns]

# %% [markdown]
# ## 5) Converter para HuggingFace Dataset

# %%
from datasets import Dataset

train_gt = Dataset.from_pandas(df_gt_train)
train_consensus = Dataset.from_pandas(df_annotations)
test_dataset = Dataset.from_pandas(df_gt_test)
eval_dataset = Dataset.from_pandas(df_gt_val)

# %% [markdown]
# ## 6) Fine-tuning

# %%
model = "roberta-base"

# %%
fine_tune_output_dir = results_dataset_path.joinpath("finetuning")

Path.mkdir(fine_tune_output_dir, parents=True, exist_ok=True)

training_args = TrainingArguments(
    output_dir=fine_tune_output_dir,
    eval_strategy="epoch",
    save_strategy="epoch",

    learning_rate=5e-5,
    num_train_epochs=20,

    per_device_train_batch_size=16,   
    per_device_eval_batch_size=32,

    weight_decay=0.01,

    load_best_model_at_end=True,
    metric_for_best_model="f1_macro",
    greater_is_better=True,

    logging_strategy="epoch",
    save_total_limit=1,

    seed=42,
)

# %%
def run_fine_tuning(model, train_dataset, test_dataset, eval_dataset = None, experiment_name: str = "default"):
    fine_tuner = SupervisedFineTuner(
        model_name=model,
        training_args=training_args,
        label_schema=label_schema,
        tokenizer=HFTokenizer(
            model_name=model,
            max_length=256
        ),
        model_factory=ModelFactory,
        trainer_builder=TrainerBuilder,
        metrics_computer=MetricsComputer(),
    )

    fine_tuner.fit(train_dataset, eval_dataset)
    metrics = fine_tuner.evaluate(test_dataset)

    metrics["source"] = experiment_name

    return metrics

# %%
metrics_consensus = run_fine_tuning(
    model=model,
    train_dataset=train_consensus,
    test_dataset=test_dataset,
    eval_dataset=eval_dataset,
    experiment_name="consensus_llm",
)
# Out:
# Map:   0%|          | 0/10653 [00:00<?, ? examples/s]
# Map:   0%|          | 0/2500 [00:00<?, ? examples/s]
# Some weights of RobertaForSequenceClassification were not initialized from the model checkpoint at roberta-base and are newly initialized: ['classifier.dense.bias', 'classifier.dense.weight', 'classifier.out_proj.bias', 'classifier.out_proj.weight']
# You should probably TRAIN this model on a down-stream task to be able to use it for predictions and inference.
# The model is already on multiple devices. Skipping the move to device specified in `args`.
#     <div>
#
#       <progress value='3' max='13320' style='width:300px; height:20px; vertical-align: middle;'></progress>
#       [    3/13320 00:00 < 1:26:51, 2.56 it/s, Epoch 0.00/20]
#     </div>
#     <table border="1" class="dataframe">
#   <thead>
#  <tr style="text-align: left;">
#       <th>Epoch</th>
#       <th>Training Loss</th>
#       <th>Validation Loss</th>
#     </tr>
#   </thead>
#   <tbody>
#   </tbody>
# </table><p>

# %%
metrics_gt = run_fine_tuning(
    model=model,
    train_dataset=train_gt,
    test_dataset=test_dataset,
    eval_dataset=eval_dataset,
    experiment_name="ground_truth",
)
# Out:
# Map:   0%|          | 0/4912 [00:00<?, ? examples/s]
# Map:   0%|          | 0/2500 [00:00<?, ? examples/s]
# Some weights of RobertaForSequenceClassification were not initialized from the model checkpoint at roberta-base and are newly initialized: ['classifier.dense.bias', 'classifier.dense.weight', 'classifier.out_proj.bias', 'classifier.out_proj.weight']
# You should probably TRAIN this model on a down-stream task to be able to use it for predictions and inference.
# The model is already on multiple devices. Skipping the move to device specified in `args`.
#     <div>
#
#       <progress value='6140' max='6140' style='width:300px; height:20px; vertical-align: middle;'></progress>
#       [6140/6140 1:37:31, Epoch 20/20]
#     </div>
#     <table border="1" class="dataframe">
#   <thead>
#  <tr style="text-align: left;">
#       <th>Epoch</th>
#       <th>Training Loss</th>
#       <th>Validation Loss</th>
#       <th>Accuracy</th>
#       <th>F1 Macro</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>1</td>
#       <td>1.276900</td>
#       <td>0.915494</td>
#       <td>0.701200</td>
#       <td>0.649186</td>
#     </tr>
#     <tr>
#       <td>2</td>
#       <td>0.827300</td>
#       <td>0.778278</td>
#       <td>0.752800</td>
#       <td>0.735119</td>
#     </tr>
#     <tr>
#       <td>3</td>
#       <td>0.633700</td>
#       <td>0.910483</td>
#       <td>0.728400</td>
#       <td>0.662302</td>
#     </tr>
#     <tr>
#       <td>4</td>
#       <td>0.481600</td>
#       <td>0.826286</td>
#       <td>0.756400</td>
#       <td>0.742488</td>
#     </tr>
#     <tr>
#       <td>5</td>
#       <td>0.353000</td>
#       <td>0.931828</td>
#       <td>0.765600</td>
#       <td>0.746641</td>
#     </tr>
#     <tr>
#       <td>6</td>
#       <td>0.263600</td>
#       <td>1.067285</td>
#       <td>0.748400</td>
#       <td>0.728834</td>
#     </tr>
#     <tr>
#       <td>7</td>
#       <td>0.191900</td>
#       <td>1.129799</td>
#       <td>0.772800</td>
#       <td>0.753932</td>
#     </tr>
#     <tr>
#       <td>8</td>
#       <td>0.138400</td>
#       <td>1.163206</td>
#       <td>0.782400</td>
#       <td>0.758173</td>
#     </tr>
#     <tr>
#       <td>9</td>
#       <td>0.097200</td>
#       <td>1.396028</td>
#       <td>0.775600</td>
#       <td>0.751050</td>
#     </tr>
#     <tr>
#       <td>10</td>
#       <td>0.074300</td>
#       <td>1.559752</td>
#       <td>0.775600</td>
#       <td>0.757440</td>
#     </tr>
#     <tr>
#       <td>11</td>
#       <td>0.047000</td>
#       <td>1.644979</td>
#       <td>0.770800</td>
#       <td>0.752206</td>
#     </tr>
#     <tr>
#       <td>12</td>
#       <td>0.025000</td>
#       <td>1.882478</td>
#       <td>0.763600</td>
#       <td>0.740889</td>
#     </tr>
#     <tr>
#       <td>13</td>
#       <td>0.021900</td>
#       <td>1.802025</td>
#       <td>0.772400</td>
#       <td>0.742170</td>
#     </tr>
#     <tr>
#       <td>14</td>
#       <td>0.010600</td>
#       <td>2.036800</td>
#       <td>0.766000</td>
#       <td>0.737080</td>
#     </tr>
#     <tr>
#       <td>15</td>
#       <td>0.009100</td>
#       <td>2.073065</td>
#       <td>0.756800</td>
#       <td>0.735562</td>
#     </tr>
#     <tr>
#       <td>16</td>
#       <td>0.005500</td>
#       <td>1.918592</td>
#       <td>0.780400</td>
#       <td>0.763631</td>
#     </tr>
#     <tr>
#       <td>17</td>
#       <td>0.003900</td>
#       <td>1.990092</td>
#       <td>0.773600</td>
#       <td>0.752083</td>
#     </tr>
#     <tr>
#       <td>18</td>
#       <td>0.004700</td>
#       <td>1.977857</td>
#       <td>0.773600</td>
#       <td>0.751410</td>
#     </tr>
#     <tr>
#       <td>19</td>
#       <td>0.001000</td>
#       <td>2.007315</td>
#       <td>0.771200</td>
#       <td>0.748445</td>
#     </tr>
#     <tr>
#       <td>20</td>
#       <td>0.001600</td>
#       <td>1.934865</td>
#       <td>0.778800</td>
#       <td>0.754139</td>
#     </tr>
#   </tbody>
# </table><p>
# Map:   0%|          | 0/2500 [00:00<?, ? examples/s]
#     <div>
#
#       <progress value='79' max='79' style='width:300px; height:20px; vertical-align: middle;'></progress>
#       [79/79 00:36]
#     </div>

# %%
results = pd.DataFrame([metrics_consensus, metrics_gt])
results
# Out:
#    eval_loss  eval_accuracy  eval_f1_macro  eval_runtime  \
# 0   3.616076         0.6192       0.595416       35.5638
# 1   1.859884         0.7864       0.758601       37.1634
#
#    eval_samples_per_second  eval_steps_per_second  epoch         source
# 0                   70.296                  2.221   20.0  consensus_llm
# 1                   67.270                  2.126   20.0   ground_truth

# %%
results.to_csv(fine_tune_output_dir.joinpath(f"{model}_fine_tuning_results.csv"), index=False)
