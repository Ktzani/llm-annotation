# %% [markdown]
# # Fine-tuning controlado de RoBERTa (GT vs Consenso LLM)

# %% [markdown]
# ## 1) Imports e setup

# %%
import pandas as pd
from transformers import TrainingArguments
from datasets import Dataset
from pathlib import Path

import sys
from loguru import logger
import pandas as pd

logger.remove()
logger.add(
    sys.stdout,
    format="<green>{time:HH:mm:ss}</green> | <level>{level: <8}</level> | <level>{message}</level>",
    level="INFO"
)

logger.success("✓ Setup completo")

# loaders
from src.utils.data_loader import load_hf_dataset_as_dataframe

# fine-tuning system
from src.fine_tune_system.fine_tune.supervised_fine_tuner import SupervisedFineTuner
from src.fine_tune_system.core.hf_tokenizer import HFTokenizer
from src.fine_tune_system.core.model_factory import ModelFactory
from src.fine_tune_system.training.trainer_builder import TrainerBuilder
from src.fine_tune_system.training.metrics import MetricsComputer
from src.fine_tune_system.training.label_schema import LabelSchema
from src.utils.dataset_aligner import DatasetAligner
# Out:
# 12:42:26 | SUCCESS  | ✓ Setup completo

# %% [markdown]
# ## 2) Configuração do experimento

# %% [markdown]
# ### - Configurações de dataset

# %%
from src.api.schemas.dataset import DatasetConfig

DATASET_GLOBAL_CONFIG_TRAIN = DatasetConfig(
    split="train",
    combine_splits=[],
    sample_size=None,
    random_state=42,
)

DATASET_GLOBAL_CONFIG_EVAL = DatasetConfig(
    split="test",
    combine_splits=[],
    sample_size=5000,
    random_state=42,
)

# %% [markdown]
# ### - Configurações de cache

# %%
CACHE_ENABLED = True
CACHE_DIR = "C:\\Users\\gabri\\Documents\\GitHub\\llm-annotation\\data\\.cache"

# %% [markdown]
# ### - Resultados

# %%
RESULTS_DIR = "C:\\Users\\gabri\\Documents\\GitHub\\llm-annotation\\data\\results"

# %%
from src.utils.get_latest_results_date import get_latest_results_date

DATASET_NAME = "agnews"  
specific_date = "latest"

if specific_date == "latest":
    specific_date = get_latest_results_date(
        RESULTS_DIR,
        DATASET_NAME
    )
    
RESULTS_DIR = Path(RESULTS_DIR)
results_dataset_path = RESULTS_DIR.joinpath(DATASET_NAME, specific_date)

# %% [markdown]
# ## 3) Carregar Dados

# %% [markdown]
# ### - Carregando

# %%
df = pd.read_csv(results_dataset_path.joinpath("summary", "dataset_anotado_completo.csv"))

print(f"Anotado: {len(df)}")
# Out:
# Anotado: 5000

# %% [markdown]
# ### - Dataset ground_truth

# %%
df_gt_train = (
    df[["text_id", "text", "ground_truth"]]
    .rename(columns={"ground_truth": "label"})
)

# %%
from src.utils.data_loader import add_label_description

df_gt_train = add_label_description(
    df_gt_train,
    dataset_name=DATASET_NAME
)

# %%
label_schema = LabelSchema.from_dataframe(df_gt_train)
print(label_schema.id2label)
# Out:
# {0: 'world', 1: 'sports', 2: 'business', 3: 'Sci/Tech'}

# %%
df_gt_train
# Out:
#       text_id                                               text  label  \
# 0           0  "Sharapova takes out WTA Champs","Maria Sharap...      1
# 1           1  "Low-Cost Airline Enters Bankruptcy","Blaming ...      2
# 2           2  "Sun, Nvidia Design Professional Graphics Alli...      3
# 3           3  "Euro-Zone Growth Continues to Lag in 2Q (AP)"...      2
# 4           4  "Jackson #39;s LA Lakers book blames Bryant","...      1
# ...       ...                                                ...    ...
# 4995     4995  "Putin: State Firms Can Bid for YUKOS","Presid...      2
# 4996     4996  "12 Killed in Fresh Iraq Violence","BAGHDAD, 2...      0
# 4997     4997  "Dutrow #39;s gamble pays off fabulously","Des...      1
# 4998     4998  "Scottish driver David Coulthard signs for Red...      1
# 4999     4999  "Dollar Rises, Investors Eye Yields"," NEW YOR...      2
#
#      label_description
# 0               sports
# 1             business
# 2             Sci/Tech
# 3             business
# 4               sports
# ...                ...
# 4995          business
# 4996             world
# 4997            sports
# 4998            sports
# 4999          business
#
# [5000 rows x 4 columns]

# %% [markdown]
# ### - Dataset anotado

# %%
df_annotations = (
    df[["text_id", "text", "most_common_annotation"]]
    .rename(columns={"most_common_annotation": "label"})
)

# %%
df_annotations = add_label_description(
    df_annotations,
    dataset_name=DATASET_NAME
)

# %%
df_annotations
# Out:
#       text_id                                               text  label  \
# 0           0  "Sharapova takes out WTA Champs","Maria Sharap...      1
# 1           1  "Low-Cost Airline Enters Bankruptcy","Blaming ...      2
# 2           2  "Sun, Nvidia Design Professional Graphics Alli...      3
# 3           3  "Euro-Zone Growth Continues to Lag in 2Q (AP)"...      2
# 4           4  "Jackson #39;s LA Lakers book blames Bryant","...      1
# ...       ...                                                ...    ...
# 4995     4995  "Putin: State Firms Can Bid for YUKOS","Presid...      2
# 4996     4996  "12 Killed in Fresh Iraq Violence","BAGHDAD, 2...      0
# 4997     4997  "Dutrow #39;s gamble pays off fabulously","Des...      1
# 4998     4998  "Scottish driver David Coulthard signs for Red...      1
# 4999     4999  "Dollar Rises, Investors Eye Yields"," NEW YOR...      2
#
#      label_description
# 0               sports
# 1             business
# 2             Sci/Tech
# 3             business
# 4               sports
# ...                ...
# 4995          business
# 4996             world
# 4997            sports
# 4998            sports
# 4999          business
#
# [5000 rows x 4 columns]

# %% [markdown]
# ### - Removendo instancias problemáticas e invalidas

# %% [markdown]
# #### -> Invalidas

# %% [markdown]
# ##### Removendo do Ground-Truth

# %%
df_invalid_gt = df_gt_train.loc[
    df_gt_train["label"] == -1 
]

df_gt_train = df_gt_train[
        ~df_gt_train["text_id"].isin(df_invalid_gt["text_id"])
    ].reset_index(drop=True)

# %%
df_gt_train
# Out:
#       text_id                                               text  label  \
# 0           0  "Sharapova takes out WTA Champs","Maria Sharap...      1
# 1           1  "Low-Cost Airline Enters Bankruptcy","Blaming ...      2
# 2           2  "Sun, Nvidia Design Professional Graphics Alli...      3
# 3           3  "Euro-Zone Growth Continues to Lag in 2Q (AP)"...      2
# 4           4  "Jackson #39;s LA Lakers book blames Bryant","...      1
# ...       ...                                                ...    ...
# 4995     4995  "Putin: State Firms Can Bid for YUKOS","Presid...      2
# 4996     4996  "12 Killed in Fresh Iraq Violence","BAGHDAD, 2...      0
# 4997     4997  "Dutrow #39;s gamble pays off fabulously","Des...      1
# 4998     4998  "Scottish driver David Coulthard signs for Red...      1
# 4999     4999  "Dollar Rises, Investors Eye Yields"," NEW YOR...      2
#
#      label_description
# 0               sports
# 1             business
# 2             Sci/Tech
# 3             business
# 4               sports
# ...                ...
# 4995          business
# 4996             world
# 4997            sports
# 4998            sports
# 4999          business
#
# [5000 rows x 4 columns]

# %% [markdown]
# ##### Removendo da anotação

# %%
df_invalid = df_annotations.loc[
    df_annotations["label"] == -1 
]

df_annotations = df_annotations[
        ~df_annotations["text_id"].isin(df_invalid["text_id"])
    ].reset_index(drop=True)

# %%
df_annotations
# Out:
#       text_id                                               text  label  \
# 0           0  "Sharapova takes out WTA Champs","Maria Sharap...      1
# 1           1  "Low-Cost Airline Enters Bankruptcy","Blaming ...      2
# 2           2  "Sun, Nvidia Design Professional Graphics Alli...      3
# 3           3  "Euro-Zone Growth Continues to Lag in 2Q (AP)"...      2
# 4           4  "Jackson #39;s LA Lakers book blames Bryant","...      1
# ...       ...                                                ...    ...
# 4995     4995  "Putin: State Firms Can Bid for YUKOS","Presid...      2
# 4996     4996  "12 Killed in Fresh Iraq Violence","BAGHDAD, 2...      0
# 4997     4997  "Dutrow #39;s gamble pays off fabulously","Des...      1
# 4998     4998  "Scottish driver David Coulthard signs for Red...      1
# 4999     4999  "Dollar Rises, Investors Eye Yields"," NEW YOR...      2
#
#      label_description
# 0               sports
# 1             business
# 2             Sci/Tech
# 3             business
# 4               sports
# ...                ...
# 4995          business
# 4996             world
# 4997            sports
# 4998            sports
# 4999          business
#
# [5000 rows x 4 columns]

# %% [markdown]
# #### -> Problematicas

# %%
problematica_cases_path = results_dataset_path.joinpath("consensus", "problematic_cases.csv")
df_problematic = None

# %% [markdown]
# ##### Removendo do Ground-Truth

# %%
if problematica_cases_path.exists():
    df_problematic = pd.read_csv(problematica_cases_path)
    df_gt_train = df_gt_train[
        ~df_gt_train["text_id"].isin(df_problematic["text_id"])
    ].reset_index(drop=True)

# %%
df_gt_train
# Out:
#       text_id                                               text  label  \
# 0           0  "Sharapova takes out WTA Champs","Maria Sharap...      1
# 1           1  "Low-Cost Airline Enters Bankruptcy","Blaming ...      2
# 2           2  "Sun, Nvidia Design Professional Graphics Alli...      3
# 3           3  "Euro-Zone Growth Continues to Lag in 2Q (AP)"...      2
# 4           4  "Jackson #39;s LA Lakers book blames Bryant","...      1
# ...       ...                                                ...    ...
# 4984     4995  "Putin: State Firms Can Bid for YUKOS","Presid...      2
# 4985     4996  "12 Killed in Fresh Iraq Violence","BAGHDAD, 2...      0
# 4986     4997  "Dutrow #39;s gamble pays off fabulously","Des...      1
# 4987     4998  "Scottish driver David Coulthard signs for Red...      1
# 4988     4999  "Dollar Rises, Investors Eye Yields"," NEW YOR...      2
#
#      label_description
# 0               sports
# 1             business
# 2             Sci/Tech
# 3             business
# 4               sports
# ...                ...
# 4984          business
# 4985             world
# 4986            sports
# 4987            sports
# 4988          business
#
# [4989 rows x 4 columns]

# %% [markdown]
# ##### Removendo da anotação

# %%
if problematica_cases_path.exists():
    df_problematic = pd.read_csv(problematica_cases_path)
    df_annotations = df_annotations[
        ~df_annotations["text_id"].isin(df_problematic["text_id"])
    ].reset_index(drop=True)

# %%
df_annotations
# Out:
#       text_id                                               text  label  \
# 0           0  "Sharapova takes out WTA Champs","Maria Sharap...      1
# 1           1  "Low-Cost Airline Enters Bankruptcy","Blaming ...      2
# 2           2  "Sun, Nvidia Design Professional Graphics Alli...      3
# 3           3  "Euro-Zone Growth Continues to Lag in 2Q (AP)"...      2
# 4           4  "Jackson #39;s LA Lakers book blames Bryant","...      1
# ...       ...                                                ...    ...
# 4984     4995  "Putin: State Firms Can Bid for YUKOS","Presid...      2
# 4985     4996  "12 Killed in Fresh Iraq Violence","BAGHDAD, 2...      0
# 4986     4997  "Dutrow #39;s gamble pays off fabulously","Des...      1
# 4987     4998  "Scottish driver David Coulthard signs for Red...      1
# 4988     4999  "Dollar Rises, Investors Eye Yields"," NEW YOR...      2
#
#      label_description
# 0               sports
# 1             business
# 2             Sci/Tech
# 3             business
# 4               sports
# ...                ...
# 4984          business
# 4985             world
# 4986            sports
# 4987            sports
# 4988          business
#
# [4989 rows x 4 columns]

# %% [markdown]
# ### - Carrega dataset de teste e validação

# %%
df_eval, _ = load_hf_dataset_as_dataframe(
    dataset_name=DATASET_NAME,
    cache_dir=CACHE_DIR,
    dataset_global_config=DATASET_GLOBAL_CONFIG_EVAL,
)

print(f"Avaliação HF: {len(df_eval)}")
# Out:
# 12:42:29 | Carregando dataset: agnews
# 12:42:33 | Split 'test': 127600 exemplos
# 12:42:33 | Categorias extraídas automaticamente: [0, 1, 2, 3]
# 12:42:33 | Amostra reduzida para 5000 exemplos (seed=42)
# 12:42:33 | Coluna de texto: text
# 12:42:33 | Ground truth carregado da coluna 'label'
# 12:42:33 | DataFrame criado com 5000 linhas
# Avaliação HF: 5000

# %%
from sklearn.model_selection import train_test_split

df_gt_val, df_gt_test = train_test_split(
    df_eval,
    test_size=0.5,
    random_state=42,
    stratify=df_eval["label"]
)

# %%
df_gt_val
# Out:
#                                                    text  label  \
# 333   "Onuaku Picks Syracuse","Episcopal forward Ari...      1
# 1867  "Coventry Health to Buy First Health (Reuters)...      2
# 2671  "Dual-Core Chips May Raise Software Costs","Fa...      3
# 1208  "China Looks Outside Asia for M A (Reuters)","...      2
# 511   "Friendships drive Islamic terrorists, CIA vet...      0
# ...                                                 ...    ...
# 1604  "AMD and IBM develops new technology for proce...      3
# 1929  "Xstrata makes \$5.8B bid for WMC","TOKYO (CBS...      2
# 1486  "Two Words from Bill Gates: Computer Science",...      3
# 103   "Japan unsatisfied with N.Korean probe","Japan...      0
# 2327  "All out for 29  SA in crisis","SOUTH Australi...      1
#
#      label_description
# 333             sports
# 1867          business
# 2671          Sci/Tech
# 1208          business
# 511              world
# ...                ...
# 1604          Sci/Tech
# 1929          business
# 1486          Sci/Tech
# 103              world
# 2327            sports
#
# [2500 rows x 3 columns]

# %%
df_gt_test
# Out:
#                                                    text  label  \
# 4286  "Georgia Tech Wins Easy","The third-ranked Yel...      1
# 1018  "Now what?","It was an event more than eight y...      3
# 1081  "Providence writes off Penn","Dwight Brewingto...      1
# 483   "Micron Strikes Deal With US in Price Fixing P...      3
# 2772  "Two killed in mortar attack in Baghdad","Two ...      0
# ...                                                 ...    ...
# 3337  "Mars Rovers Planners Plot Crater 'Escape' (AP...      3
# 721   "Internet calls add foreign accent (USATODAY.c...      3
# 3209  "Syracuse rolls after fast start","NO. 6 SYRAC...      1
# 20    "Lohse Continues Roll","Kyle Lohse pitches sev...      1
# 4387  "Oil Prices Hit \$53 a Barrel, Then Stage a Re...      2
#
#      label_description
# 4286            sports
# 1018          Sci/Tech
# 1081            sports
# 483           Sci/Tech
# 2772             world
# ...                ...
# 3337          Sci/Tech
# 721           Sci/Tech
# 3209            sports
# 20              sports
# 4387          business
#
# [2500 rows x 3 columns]

# %% [markdown]
# ## 5) Converter para HuggingFace Dataset

# %%
from datasets import Dataset

train_gt = Dataset.from_pandas(df_gt_train)
train_consensus = Dataset.from_pandas(df_annotations)
test_dataset = Dataset.from_pandas(df_gt_test)
eval_dataset = Dataset.from_pandas(df_gt_val)

# %% [markdown]
# ## 6) Fine-tuning

# %%
model = "roberta-base"

# %%
fine_tune_output_dir = results_dataset_path.joinpath("finetuning")

Path.mkdir(fine_tune_output_dir, parents=True, exist_ok=True)

training_args = TrainingArguments(
    output_dir=fine_tune_output_dir,
    eval_strategy="epoch",
    save_strategy="epoch",

    learning_rate=5e-5,
    num_train_epochs=20,

    per_device_train_batch_size=16,   
    per_device_eval_batch_size=32,

    weight_decay=0.01,

    load_best_model_at_end=True,
    metric_for_best_model="f1_macro",
    greater_is_better=True,

    logging_strategy="epoch",
    save_total_limit=1,

    seed=42,
)

# %%
def run_fine_tuning(model, train_dataset, test_dataset, eval_dataset = None, experiment_name: str = "default"):
    fine_tuner = SupervisedFineTuner(
        model_name=model,
        training_args=training_args,
        label_schema=label_schema,
        tokenizer=HFTokenizer(
            model_name=model,
            max_length=256
        ),
        model_factory=ModelFactory,
        trainer_builder=TrainerBuilder,
        metrics_computer=MetricsComputer(),
    )

    fine_tuner.fit(train_dataset, eval_dataset)
    metrics = fine_tuner.evaluate(test_dataset)

    metrics["source"] = experiment_name

    return metrics

# %%
metrics_consensus = run_fine_tuning(
    model=model,
    train_dataset=train_consensus,
    test_dataset=test_dataset,
    eval_dataset=eval_dataset,
    experiment_name="consensus_llm",
)
# Out:
# Map:   0%|          | 0/4989 [00:00<?, ? examples/s]
# Map:   0%|          | 0/2500 [00:00<?, ? examples/s]
# Some weights of RobertaForSequenceClassification were not initialized from the model checkpoint at roberta-base and are newly initialized: ['classifier.dense.bias', 'classifier.dense.weight', 'classifier.out_proj.bias', 'classifier.out_proj.weight']
# You should probably TRAIN this model on a down-stream task to be able to use it for predictions and inference.
# The model is already on multiple devices. Skipping the move to device specified in `args`.
#     <div>
#
#       <progress value='184' max='6240' style='width:300px; height:20px; vertical-align: middle;'></progress>
#       [ 184/6240 01:49 < 1:00:54, 1.66 it/s, Epoch 0.59/20]
#     </div>
#     <table border="1" class="dataframe">
#   <thead>
#  <tr style="text-align: left;">
#       <th>Epoch</th>
#       <th>Training Loss</th>
#       <th>Validation Loss</th>
#     </tr>
#   </thead>
#   <tbody>
#   </tbody>
# </table><p>

# %%
metrics_gt = run_fine_tuning(
    model=model,
    train_dataset=train_gt,
    test_dataset=test_dataset,
    eval_dataset=eval_dataset,
    experiment_name="ground_truth",
)
# Out:
# Map:   0%|          | 0/5000 [00:00<?, ? examples/s]
# Map:   0%|          | 0/2500 [00:00<?, ? examples/s]
# Some weights of RobertaForSequenceClassification were not initialized from the model checkpoint at roberta-base and are newly initialized: ['classifier.dense.bias', 'classifier.dense.weight', 'classifier.out_proj.bias', 'classifier.out_proj.weight']
# You should probably TRAIN this model on a down-stream task to be able to use it for predictions and inference.
# The model is already on multiple devices. Skipping the move to device specified in `args`.
#     <div>
#
#       <progress value='6260' max='6260' style='width:300px; height:20px; vertical-align: middle;'></progress>
#       [6260/6260 1:24:28, Epoch 20/20]
#     </div>
#     <table border="1" class="dataframe">
#   <thead>
#  <tr style="text-align: left;">
#       <th>Epoch</th>
#       <th>Training Loss</th>
#       <th>Validation Loss</th>
#       <th>Accuracy</th>
#       <th>F1 Macro</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>1</td>
#       <td>1.354300</td>
#       <td>1.217204</td>
#       <td>0.455600</td>
#       <td>0.367447</td>
#     </tr>
#     <tr>
#       <td>2</td>
#       <td>1.017300</td>
#       <td>1.088655</td>
#       <td>0.576800</td>
#       <td>0.554859</td>
#     </tr>
#     <tr>
#       <td>3</td>
#       <td>0.806300</td>
#       <td>0.999335</td>
#       <td>0.618800</td>
#       <td>0.602298</td>
#     </tr>
#     <tr>
#       <td>4</td>
#       <td>0.577800</td>
#       <td>1.076898</td>
#       <td>0.638400</td>
#       <td>0.625499</td>
#     </tr>
#     <tr>
#       <td>5</td>
#       <td>0.420400</td>
#       <td>1.151666</td>
#       <td>0.638000</td>
#       <td>0.632655</td>
#     </tr>
#     <tr>
#       <td>6</td>
#       <td>0.299300</td>
#       <td>1.445358</td>
#       <td>0.632800</td>
#       <td>0.625578</td>
#     </tr>
#     <tr>
#       <td>7</td>
#       <td>0.274100</td>
#       <td>1.572421</td>
#       <td>0.663600</td>
#       <td>0.657928</td>
#     </tr>
#     <tr>
#       <td>8</td>
#       <td>0.217400</td>
#       <td>1.777372</td>
#       <td>0.672400</td>
#       <td>0.668399</td>
#     </tr>
#     <tr>
#       <td>9</td>
#       <td>0.150200</td>
#       <td>2.138284</td>
#       <td>0.661600</td>
#       <td>0.651067</td>
#     </tr>
#     <tr>
#       <td>10</td>
#       <td>0.148300</td>
#       <td>2.183770</td>
#       <td>0.673200</td>
#       <td>0.668647</td>
#     </tr>
#     <tr>
#       <td>11</td>
#       <td>0.108700</td>
#       <td>2.327429</td>
#       <td>0.662800</td>
#       <td>0.654448</td>
#     </tr>
#     <tr>
#       <td>12</td>
#       <td>0.089300</td>
#       <td>2.433417</td>
#       <td>0.665600</td>
#       <td>0.661253</td>
#     </tr>
#     <tr>
#       <td>13</td>
#       <td>0.042800</td>
#       <td>2.572056</td>
#       <td>0.690400</td>
#       <td>0.678550</td>
#     </tr>
#     <tr>
#       <td>14</td>
#       <td>0.052600</td>
#       <td>2.793589</td>
#       <td>0.676400</td>
#       <td>0.672385</td>
#     </tr>
#     <tr>
#       <td>15</td>
#       <td>0.037400</td>
#       <td>2.784568</td>
#       <td>0.686000</td>
#       <td>0.679198</td>
#     </tr>
#     <tr>
#       <td>16</td>
#       <td>0.035400</td>
#       <td>2.816971</td>
#       <td>0.685600</td>
#       <td>0.677382</td>
#     </tr>
#     <tr>
#       <td>17</td>
#       <td>0.025700</td>
#       <td>2.807340</td>
#       <td>0.692400</td>
#       <td>0.684260</td>
#     </tr>
#     <tr>
#       <td>18</td>
#       <td>0.013800</td>
#       <td>2.827309</td>
#       <td>0.691200</td>
#       <td>0.684019</td>
#     </tr>
#     <tr>
#       <td>19</td>
#       <td>0.012300</td>
#       <td>2.848875</td>
#       <td>0.694000</td>
#       <td>0.685201</td>
#     </tr>
#     <tr>
#       <td>20</td>
#       <td>0.006800</td>
#       <td>2.885934</td>
#       <td>0.692400</td>
#       <td>0.683579</td>
#     </tr>
#   </tbody>
# </table><p>
# Map:   0%|          | 0/2500 [00:00<?, ? examples/s]
#     <div>
#
#       <progress value='79' max='79' style='width:300px; height:20px; vertical-align: middle;'></progress>
#       [79/79 00:20]
#     </div>

# %%
results = pd.DataFrame([metrics_consensus, metrics_gt])
results
# Out:
#    eval_loss  eval_accuracy  eval_f1_macro  eval_runtime  \
# 0   3.048118         0.5096       0.472486       44.2883
# 1   2.928392         0.6812       0.674524       20.5520
#
#    eval_samples_per_second  eval_steps_per_second  epoch         source
# 0                   56.448                  1.784   20.0  consensus_llm
# 1                  121.643                  3.844   20.0   ground_truth

# %%
results.to_csv(fine_tune_output_dir.joinpath(f"{model}_fine_tuning_results.csv"), index=False)
