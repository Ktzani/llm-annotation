# %% [markdown]
# # Fine-tuning controlado de RoBERTa (GT vs Consenso LLM)

# %% [markdown]
# ## 1) Imports e setup

# %%
import pandas as pd
from transformers import TrainingArguments
from datasets import Dataset
from pathlib import Path

import sys
from loguru import logger
import pandas as pd

logger.remove()
logger.add(
    sys.stdout,
    format="<green>{time:HH:mm:ss}</green> | <level>{level: <8}</level> | <level>{message}</level>",
    level="INFO"
)

logger.success("✓ Setup completo")

# loaders
from src.utils.data_loader import load_hf_dataset_as_dataframe

# fine-tuning system
from src.fine_tune_system.fine_tune.supervised_fine_tuner import SupervisedFineTuner
from src.fine_tune_system.core.hf_tokenizer import HFTokenizer
from src.fine_tune_system.core.model_factory import ModelFactory
from src.fine_tune_system.training.trainer_builder import TrainerBuilder
from src.fine_tune_system.training.metrics import MetricsComputer
from src.fine_tune_system.training.label_schema import LabelSchema
from src.utils.dataset_aligner import DatasetAligner
# Out:
# 13:55:00 | SUCCESS  | ✓ Setup completo

# %% [markdown]
# ## 2) Configuração do experimento

# %% [markdown]
# ### - Configurações de dataset

# %%
from src.api.schemas.dataset import DatasetConfig

DATASET_GLOBAL_CONFIG_TRAIN = DatasetConfig(
    split="train",
    combine_splits=[],
    sample_size=None,
    random_state=42,
)

DATASET_GLOBAL_CONFIG_EVAL = DatasetConfig(
    split="test",
    combine_splits=[],
    sample_size=5000,
    random_state=42,
)

# %% [markdown]
# ### - Configurações de cache

# %%
CACHE_ENABLED = True
CACHE_DIR = "C:\\Users\\gabri\\Documents\\GitHub\\llm-annotation\\data\\.cache"

# %% [markdown]
# ### - Resultados

# %%
RESULTS_DIR = "C:\\Users\\gabri\\Documents\\GitHub\\llm-annotation\\data\\results"

# %%
DATASET_NAME = "sst1"  
SPECIFIC_DATE = "2025-12-27"

RESULTS_DIR = Path(RESULTS_DIR)
results_dataset_path = RESULTS_DIR.joinpath(DATASET_NAME, SPECIFIC_DATE)

# %% [markdown]
# ## 3) Carregar Dados

# %% [markdown]
# ### - Carregando

# %%
df = pd.read_csv(results_dataset_path.joinpath("summary", "dataset_anotado_completo.csv"))

print(f"Anotado: {len(df)}")
# Out:
# Anotado: 5000

# %% [markdown]
# ### - Dataset ground_truth

# %%
df_gt_train = (
    df[["text_id", "text", "ground_truth"]]
    .rename(columns={"ground_truth": "label"})
)

# %%
from src.utils.data_loader import add_label_description

df_gt_train = add_label_description(
    df_gt_train,
    dataset_name=DATASET_NAME
)

# %%
label_schema = LabelSchema.from_dataframe(df_gt_train)
print(label_schema.id2label)
# Out:
# {0: 'very negative sentiment', 1: 'negative sentiment', 2: 'neutral sentiment', 3: 'positive sentiment', 4: 'very positive sentiment'}

# %%
df_gt_train
# Out:
#       text_id                                               text  label  \
# 0           0  impostor has a handful of thrilling moments an...      1
# 1           1  the acting in pauline and paulette is good all...      4
# 2           2  mr. polanski is in his element here : alone , ...      3
# 3           3  a cop story that understands the medium amazin...      3
# 4           4  the most horrific movie experience i 've had s...      0
# ...       ...                                                ...    ...
# 4995     4995                                    remember it .\n      3
# 4996     4996  -lrb- woo 's -rrb- most resonant film since th...      3
# 4997     4997  it 's a movie that accomplishes so much that o...      3
# 4998     4998  a different movie -- sometimes tedious -- by a...      3
# 4999     4999  ... a visually seductive , unrepentantly trash...      2
#
#             label_description
# 0          negative sentiment
# 1     very positive sentiment
# 2          positive sentiment
# 3          positive sentiment
# 4     very negative sentiment
# ...                       ...
# 4995       positive sentiment
# 4996       positive sentiment
# 4997       positive sentiment
# 4998       positive sentiment
# 4999        neutral sentiment
#
# [5000 rows x 4 columns]

# %% [markdown]
# ### - Dataset anotado

# %%
df_annotations = (
    df[["text_id", "text", "most_common_annotation"]]
    .rename(columns={"most_common_annotation": "label"})
)

# %%
df_annotations = add_label_description(
    df_annotations,
    dataset_name=DATASET_NAME
)

# %%
df_annotations
# Out:
#       text_id                                               text  label  \
# 0           0  impostor has a handful of thrilling moments an...      1
# 1           1  the acting in pauline and paulette is good all...      3
# 2           2  mr. polanski is in his element here : alone , ...      3
# 3           3  a cop story that understands the medium amazin...      3
# 4           4  the most horrific movie experience i 've had s...      1
# ...       ...                                                ...    ...
# 4995     4995                                    remember it .\n      2
# 4996     4996  -lrb- woo 's -rrb- most resonant film since th...      3
# 4997     4997  it 's a movie that accomplishes so much that o...      3
# 4998     4998  a different movie -- sometimes tedious -- by a...      1
# 4999     4999  ... a visually seductive , unrepentantly trash...      1
#
#        label_description
# 0     negative sentiment
# 1     positive sentiment
# 2     positive sentiment
# 3     positive sentiment
# 4     negative sentiment
# ...                  ...
# 4995   neutral sentiment
# 4996  positive sentiment
# 4997  positive sentiment
# 4998  negative sentiment
# 4999  negative sentiment
#
# [5000 rows x 4 columns]

# %% [markdown]
# ### - Removendo instancias problemáticas

# %%
df_problematic = pd.read_csv(results_dataset_path.joinpath("consensus", "problematic_cases.csv"))

df_problematic
# Out:
#       text_id                                               text  \
# 0           5  massoud 's story is an epic , but also a trage...
# 1           9  if you saw benigni 's pinocchio at a public pa...
# 2          12  meant to reduce blake 's philosophy into a tra...
# 3          16  if the predictability of bland comfort food ap...
# 4          17  what they 're doing is a matter of plumbing ar...
# ...       ...                                                ...
# 1024     4961  an intelligent , multi-layered and profoundly ...
# 1025     4972  the best part about `` gangs '' was daniel day...
# 1026     4975  any one episode of the sopranos would send thi...
# 1027     4987  strange occurrences build in the mind of the v...
# 1028     4994  i have returned from the beyond to warn you : ...
#
#       consensus_score               annotations   entropy
# 0                 0.4  {1: 2, 3: 1, 4: 1, 2: 1}  1.921928
# 1                 0.4        {0: 2, 1: 2, 4: 1}  1.521928
# 2                 0.4        {1: 2, 2: 2, 4: 1}  1.521928
# 3                 0.4        {3: 2, 2: 2, 4: 1}  1.521928
# 4                 0.4        {1: 2, 2: 2, 4: 1}  1.521928
# ...               ...                       ...       ...
# 1024              0.4        {4: 2, 3: 2, 2: 1}  1.521928
# 1025              0.4        {3: 2, 1: 2, 4: 1}  1.521928
# 1026              0.4        {0: 2, 1: 2, 4: 1}  1.521928
# 1027              0.4  {0: 1, 1: 2, 4: 1, 2: 1}  1.921928
# 1028              0.4  {1: 2, 0: 1, 4: 1, 3: 1}  1.921928
#
# [1029 rows x 5 columns]

# %%
df_annotations = df_annotations[
    ~df_annotations["text_id"].isin(df_problematic["text_id"])
].reset_index(drop=True)

# %%
df_annotations
# Out:
#       text_id                                               text  label  \
# 0           0  impostor has a handful of thrilling moments an...      1
# 1           1  the acting in pauline and paulette is good all...      3
# 2           2  mr. polanski is in his element here : alone , ...      3
# 3           3  a cop story that understands the medium amazin...      3
# 4           4  the most horrific movie experience i 've had s...      1
# ...       ...                                                ...    ...
# 3966     4995                                    remember it .\n      2
# 3967     4996  -lrb- woo 's -rrb- most resonant film since th...      3
# 3968     4997  it 's a movie that accomplishes so much that o...      3
# 3969     4998  a different movie -- sometimes tedious -- by a...      1
# 3970     4999  ... a visually seductive , unrepentantly trash...      1
#
#        label_description
# 0     negative sentiment
# 1     positive sentiment
# 2     positive sentiment
# 3     positive sentiment
# 4     negative sentiment
# ...                  ...
# 3966   neutral sentiment
# 3967  positive sentiment
# 3968  positive sentiment
# 3969  negative sentiment
# 3970  negative sentiment
#
# [3971 rows x 4 columns]

# %% [markdown]
# ### - Carrega dataset de teste e validação

# %%
df_eval, _ = load_hf_dataset_as_dataframe(
    dataset_name=DATASET_NAME,
    cache_dir=CACHE_DIR,
    dataset_global_config=DATASET_GLOBAL_CONFIG_EVAL,
)

print(f"Avaliação HF: {len(df_eval)}")
# Out:
# 13:55:06 | Carregando dataset: sst1
# Downloading readme:   0%|          | 0.00/965 [00:00<?, ?B/s]
# 13:55:12 | Split 'test': 11855 exemplos
# 13:55:12 | Categorias extraídas automaticamente: [0, 1, 2, 3, 4]
# 13:55:12 | Amostra reduzida para 5000 exemplos (seed=42)
# 13:55:12 | Coluna de texto: text
# 13:55:13 | Ground truth carregado da coluna 'label'
# 13:55:13 | DataFrame criado com 5000 linhas
# Avaliação HF: 5000

# %%
from sklearn.model_selection import train_test_split

df_gt_val, df_gt_test = train_test_split(
    df_eval,
    test_size=0.5,
    random_state=42,
    stratify=df_eval["label"]
)

# %%
df_gt_val
# Out:
#                                                    text  label  \
# 173   cox is far more concerned with aggrandizing ma...      2
# 39    much of the lady and the duke is about quiet ,...      3
# 1099  victor rosa is leguizamo 's best movie work so...      4
# 4458  the year 's happiest surprise , a movie that d...      4
# 874   the irwins emerge unscathed , but the fictiona...      0
# ...                                                 ...    ...
# 1669          both deeply weird and charmingly dear .\n      3
# 4049  it 's a testament to de niro and director mich...      3
# 486   without the dark spookiness of crystal lake ca...      2
# 2561  everything is pegged into the groove of a new ...      2
# 2433  a captivating coming-of-age story that may als...      4
#
#             label_description
# 173         neutral sentiment
# 39         positive sentiment
# 1099  very positive sentiment
# 4458  very positive sentiment
# 874   very negative sentiment
# ...                       ...
# 1669       positive sentiment
# 4049       positive sentiment
# 486         neutral sentiment
# 2561        neutral sentiment
# 2433  very positive sentiment
#
# [2500 rows x 3 columns]

# %%
df_gt_test
# Out:
#                                                    text  label  \
# 24    not so much a movie as a picture book for the ...      1
# 3023  adolescents will be adequately served by the m...      3
# 1136  tsai ming-liang 's ghosts are painfully aware ...      2
# 4956  where tom green stages his gags as assaults on...      1
# 4571  the word that comes to mind , while watching e...      3
# ...                                                 ...    ...
# 1284  labute 's careful handling makes the material ...      4
# 4996  the town has kind of an authentic feel , but e...      1
# 2967  thanks to ice cube , benjamins feels an awful ...      2
# 235   i have a confession to make : i did n't partic...      1
# 2672  like being able to hit on a 15-year old when y...      1
#
#             label_description
# 24         negative sentiment
# 3023       positive sentiment
# 1136        neutral sentiment
# 4956       negative sentiment
# 4571       positive sentiment
# ...                       ...
# 1284  very positive sentiment
# 4996       negative sentiment
# 2967        neutral sentiment
# 235        negative sentiment
# 2672       negative sentiment
#
# [2500 rows x 3 columns]

# %% [markdown]
# ## 5) Converter para HuggingFace Dataset

# %%
from datasets import Dataset

train_gt = Dataset.from_pandas(df_gt_train)
train_consensus = Dataset.from_pandas(df_annotations)
test_dataset = Dataset.from_pandas(df_gt_test)
eval_dataset = Dataset.from_pandas(df_gt_val)

# %% [markdown]
# ## 6) Fine-tuning

# %%
model = "roberta-base"

# %%
fine_tune_output_dir = results_dataset_path.joinpath("finetuning")

Path.mkdir(fine_tune_output_dir, parents=True, exist_ok=True)

training_args = TrainingArguments(
    output_dir=fine_tune_output_dir,
    eval_strategy="epoch",
    save_strategy="epoch",

    learning_rate=5e-5,
    num_train_epochs=20,

    per_device_train_batch_size=16,   
    per_device_eval_batch_size=32,

    weight_decay=0.01,

    load_best_model_at_end=True,
    metric_for_best_model="f1_macro",
    greater_is_better=True,

    logging_strategy="epoch",
    save_total_limit=1,

    seed=42,
)

# %%
def run_fine_tuning(model, train_dataset, test_dataset, eval_dataset = None, experiment_name: str = "default"):
    fine_tuner = SupervisedFineTuner(
        model_name=model,
        training_args=training_args,
        label_schema=label_schema,
        tokenizer=HFTokenizer(
            model_name=model,
            max_length=256
        ),
        model_factory=ModelFactory,
        trainer_builder=TrainerBuilder,
        metrics_computer=MetricsComputer(),
    )

    fine_tuner.fit(train_dataset, eval_dataset)
    metrics = fine_tuner.evaluate(test_dataset)

    metrics["source"] = experiment_name

    return metrics

# %%
metrics_consensus = run_fine_tuning(
    model=model,
    train_dataset=train_consensus,
    test_dataset=test_dataset,
    eval_dataset=eval_dataset,
    experiment_name="consensus_llm",
)
# Out:
# Map:   0%|          | 0/3971 [00:00<?, ? examples/s]
# Map:   0%|          | 0/2500 [00:00<?, ? examples/s]
# Some weights of RobertaForSequenceClassification were not initialized from the model checkpoint at roberta-base and are newly initialized: ['classifier.dense.bias', 'classifier.dense.weight', 'classifier.out_proj.bias', 'classifier.out_proj.weight']
# You should probably TRAIN this model on a down-stream task to be able to use it for predictions and inference.
# The model is already on multiple devices. Skipping the move to device specified in `args`.
#     <div>
#
#       <progress value='4980' max='4980' style='width:300px; height:20px; vertical-align: middle;'></progress>
#       [4980/4980 40:28, Epoch 20/20]
#     </div>
#     <table border="1" class="dataframe">
#   <thead>
#  <tr style="text-align: left;">
#       <th>Epoch</th>
#       <th>Training Loss</th>
#       <th>Validation Loss</th>
#       <th>Accuracy</th>
#       <th>F1 Macro</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>1</td>
#       <td>0.748600</td>
#       <td>2.016700</td>
#       <td>0.430400</td>
#       <td>0.256347</td>
#     </tr>
#     <tr>
#       <td>2</td>
#       <td>0.478200</td>
#       <td>2.376189</td>
#       <td>0.444400</td>
#       <td>0.289095</td>
#     </tr>
#     <tr>
#       <td>3</td>
#       <td>0.342500</td>
#       <td>2.767248</td>
#       <td>0.464400</td>
#       <td>0.303403</td>
#     </tr>
#     <tr>
#       <td>4</td>
#       <td>0.284500</td>
#       <td>2.750978</td>
#       <td>0.460400</td>
#       <td>0.289646</td>
#     </tr>
#     <tr>
#       <td>5</td>
#       <td>0.209200</td>
#       <td>3.316910</td>
#       <td>0.450000</td>
#       <td>0.291615</td>
#     </tr>
#     <tr>
#       <td>6</td>
#       <td>0.137200</td>
#       <td>3.800683</td>
#       <td>0.454000</td>
#       <td>0.309901</td>
#     </tr>
#     <tr>
#       <td>7</td>
#       <td>0.085500</td>
#       <td>4.075778</td>
#       <td>0.472400</td>
#       <td>0.317644</td>
#     </tr>
#     <tr>
#       <td>8</td>
#       <td>0.068300</td>
#       <td>4.279271</td>
#       <td>0.472800</td>
#       <td>0.317395</td>
#     </tr>
#     <tr>
#       <td>9</td>
#       <td>0.057400</td>
#       <td>4.601912</td>
#       <td>0.458400</td>
#       <td>0.298529</td>
#     </tr>
#     <tr>
#       <td>10</td>
#       <td>0.039100</td>
#       <td>4.527915</td>
#       <td>0.476400</td>
#       <td>0.324636</td>
#     </tr>
#     <tr>
#       <td>11</td>
#       <td>0.021300</td>
#       <td>4.581373</td>
#       <td>0.468000</td>
#       <td>0.315652</td>
#     </tr>
#     <tr>
#       <td>12</td>
#       <td>0.013100</td>
#       <td>4.867476</td>
#       <td>0.466000</td>
#       <td>0.315572</td>
#     </tr>
#     <tr>
#       <td>13</td>
#       <td>0.016200</td>
#       <td>4.893958</td>
#       <td>0.479600</td>
#       <td>0.325398</td>
#     </tr>
#     <tr>
#       <td>14</td>
#       <td>0.011400</td>
#       <td>5.095378</td>
#       <td>0.473600</td>
#       <td>0.321047</td>
#     </tr>
#     <tr>
#       <td>15</td>
#       <td>0.014300</td>
#       <td>5.018709</td>
#       <td>0.476000</td>
#       <td>0.320722</td>
#     </tr>
#     <tr>
#       <td>16</td>
#       <td>0.007500</td>
#       <td>5.119242</td>
#       <td>0.474400</td>
#       <td>0.322628</td>
#     </tr>
#     <tr>
#       <td>17</td>
#       <td>0.008500</td>
#       <td>5.334685</td>
#       <td>0.465600</td>
#       <td>0.309493</td>
#     </tr>
#     <tr>
#       <td>18</td>
#       <td>0.014800</td>
#       <td>5.227056</td>
#       <td>0.467600</td>
#       <td>0.320128</td>
#     </tr>
#     <tr>
#       <td>19</td>
#       <td>0.009300</td>
#       <td>5.265652</td>
#       <td>0.468400</td>
#       <td>0.313743</td>
#     </tr>
#     <tr>
#       <td>20</td>
#       <td>0.006400</td>
#       <td>5.319751</td>
#       <td>0.465200</td>
#       <td>0.307403</td>
#     </tr>
#   </tbody>
# </table><p>
# Map:   0%|          | 0/2500 [00:00<?, ? examples/s]
#     <div>
#
#       <progress value='79' max='79' style='width:300px; height:20px; vertical-align: middle;'></progress>
#       [79/79 00:18]
#     </div>

# %%
metrics_gt = run_fine_tuning(
    model=model,
    train_dataset=train_gt,
    test_dataset=test_dataset,
    eval_dataset=eval_dataset,
    experiment_name="ground_truth",
)
# Out:
# Map:   0%|          | 0/5000 [00:00<?, ? examples/s]
# Map:   0%|          | 0/2500 [00:00<?, ? examples/s]
# Some weights of RobertaForSequenceClassification were not initialized from the model checkpoint at roberta-base and are newly initialized: ['classifier.dense.bias', 'classifier.dense.weight', 'classifier.out_proj.bias', 'classifier.out_proj.weight']
# You should probably TRAIN this model on a down-stream task to be able to use it for predictions and inference.
# The model is already on multiple devices. Skipping the move to device specified in `args`.
#     <div>
#
#       <progress value='6260' max='6260' style='width:300px; height:20px; vertical-align: middle;'></progress>
#       [6260/6260 49:12, Epoch 20/20]
#     </div>
#     <table border="1" class="dataframe">
#   <thead>
#  <tr style="text-align: left;">
#       <th>Epoch</th>
#       <th>Training Loss</th>
#       <th>Validation Loss</th>
#       <th>Accuracy</th>
#       <th>F1 Macro</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>1</td>
#       <td>1.582600</td>
#       <td>1.571604</td>
#       <td>0.260800</td>
#       <td>0.082741</td>
#     </tr>
#     <tr>
#       <td>2</td>
#       <td>1.576900</td>
#       <td>1.574779</td>
#       <td>0.267200</td>
#       <td>0.084343</td>
#     </tr>
#     <tr>
#       <td>3</td>
#       <td>1.576500</td>
#       <td>1.575871</td>
#       <td>0.267200</td>
#       <td>0.084343</td>
#     </tr>
#     <tr>
#       <td>4</td>
#       <td>1.540100</td>
#       <td>1.505087</td>
#       <td>0.326400</td>
#       <td>0.182228</td>
#     </tr>
#     <tr>
#       <td>5</td>
#       <td>1.560800</td>
#       <td>1.579022</td>
#       <td>0.267200</td>
#       <td>0.084343</td>
#     </tr>
#     <tr>
#       <td>6</td>
#       <td>1.572100</td>
#       <td>1.579028</td>
#       <td>0.260800</td>
#       <td>0.082741</td>
#     </tr>
#     <tr>
#       <td>7</td>
#       <td>1.571300</td>
#       <td>1.574764</td>
#       <td>0.267200</td>
#       <td>0.084343</td>
#     </tr>
#     <tr>
#       <td>8</td>
#       <td>1.570100</td>
#       <td>1.573490</td>
#       <td>0.260800</td>
#       <td>0.082741</td>
#     </tr>
#     <tr>
#       <td>9</td>
#       <td>1.571500</td>
#       <td>1.581846</td>
#       <td>0.267200</td>
#       <td>0.084343</td>
#     </tr>
#     <tr>
#       <td>10</td>
#       <td>1.570500</td>
#       <td>1.572051</td>
#       <td>0.260800</td>
#       <td>0.082741</td>
#     </tr>
#     <tr>
#       <td>11</td>
#       <td>1.571700</td>
#       <td>1.571288</td>
#       <td>0.267200</td>
#       <td>0.084343</td>
#     </tr>
#     <tr>
#       <td>12</td>
#       <td>1.570300</td>
#       <td>1.574661</td>
#       <td>0.260800</td>
#       <td>0.082741</td>
#     </tr>
#     <tr>
#       <td>13</td>
#       <td>1.536900</td>
#       <td>1.517499</td>
#       <td>0.298800</td>
#       <td>0.130285</td>
#     </tr>
#     <tr>
#       <td>14</td>
#       <td>1.494800</td>
#       <td>1.487018</td>
#       <td>0.350000</td>
#       <td>0.181394</td>
#     </tr>
#     <tr>
#       <td>15</td>
#       <td>1.483100</td>
#       <td>1.481197</td>
#       <td>0.353200</td>
#       <td>0.182147</td>
#     </tr>
#     <tr>
#       <td>16</td>
#       <td>1.476400</td>
#       <td>1.480295</td>
#       <td>0.346400</td>
#       <td>0.176248</td>
#     </tr>
#     <tr>
#       <td>17</td>
#       <td>1.469400</td>
#       <td>1.501205</td>
#       <td>0.332000</td>
#       <td>0.184640</td>
#     </tr>
#     <tr>
#       <td>18</td>
#       <td>1.494100</td>
#       <td>1.477560</td>
#       <td>0.341600</td>
#       <td>0.218915</td>
#     </tr>
#     <tr>
#       <td>19</td>
#       <td>1.517000</td>
#       <td>1.462032</td>
#       <td>0.373200</td>
#       <td>0.237155</td>
#     </tr>
#     <tr>
#       <td>20</td>
#       <td>1.452000</td>
#       <td>1.462666</td>
#       <td>0.372400</td>
#       <td>0.255704</td>
#     </tr>
#   </tbody>
# </table><p>
# Map:   0%|          | 0/2500 [00:00<?, ? examples/s]
#     <div>
#
#       <progress value='79' max='79' style='width:300px; height:20px; vertical-align: middle;'></progress>
#       [79/79 00:18]
#     </div>

# %%
results = pd.DataFrame([metrics_consensus, metrics_gt])
results
# Out:
#    eval_loss  eval_accuracy  eval_f1_macro  eval_runtime  \
# 0   5.052509         0.4608       0.299412       18.7065
# 1   1.461705         0.3624       0.247437       18.6866
#
#    eval_samples_per_second  eval_steps_per_second  epoch         source
# 0                  133.643                  4.223   20.0  consensus_llm
# 1                  133.785                  4.228   20.0   ground_truth

# %%
results.to_csv(fine_tune_output_dir.joinpath(f"{model}_fine_tuning_results.csv"), index=False)
