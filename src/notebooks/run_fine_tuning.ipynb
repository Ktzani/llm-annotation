# %% [markdown]
# # Fine-tuning controlado de RoBERTa (GT vs Consenso LLM)

# %% [markdown]
# ## 1) Imports e setup

# %%
import pandas as pd
from transformers import TrainingArguments
from datasets import Dataset
from pathlib import Path

import sys
from loguru import logger
import pandas as pd

logger.remove()
logger.add(
    sys.stdout,
    format="<green>{time:HH:mm:ss}</green> | <level>{level: <8}</level> | <level>{message}</level>",
    level="INFO"
)

logger.success("✓ Setup completo")

# loaders
from src.utils.data_loader import load_hf_dataset_as_dataframe

# fine-tuning system
from src.fine_tune_system.fine_tune.supervised_fine_tuner import SupervisedFineTuner
from src.fine_tune_system.core.hf_tokenizer import HFTokenizer
from src.fine_tune_system.core.model_factory import ModelFactory
from src.fine_tune_system.training.trainer_builder import TrainerBuilder
from src.fine_tune_system.training.metrics import MetricsComputer
from src.fine_tune_system.training.label_schema import LabelSchema
from src.utils.dataset_aligner import DatasetAligner
# Out:
# 12:13:06 | SUCCESS  | ✓ Setup completo

# %% [markdown]
# ## 2) Configuração do experimento

# %% [markdown]
# ### - Configurações de dataset

# %%
from src.api.schemas.dataset import DatasetConfig

DATASET_GLOBAL_CONFIG_TRAIN = DatasetConfig(
    split="train",
    combine_splits=[],
    sample_size=None,
    random_state=42,
)

DATASET_GLOBAL_CONFIG_EVAL = DatasetConfig(
    split="test",
    combine_splits=[],
    sample_size=5000,
    random_state=42,
)

# %% [markdown]
# ### - Configurações de cache

# %%
CACHE_ENABLED = True
CACHE_DIR = "C:\\Users\\gabri\\Documents\\GitHub\\llm-annotation\\data\\.cache"

# %% [markdown]
# ### - Resultados

# %%
RESULTS_DIR = "C:\\Users\\gabri\\Documents\\GitHub\\llm-annotation\\data\\results"

# %%
from src.utils.get_latest_results_date import get_latest_results_date

DATASET_NAME = "sst1"  
specific_date = "latest"

if specific_date == "latest":
    specific_date = get_latest_results_date(
        RESULTS_DIR,
        DATASET_NAME
    )
    
RESULTS_DIR = Path(RESULTS_DIR)
results_dataset_path = RESULTS_DIR.joinpath(DATASET_NAME, specific_date)

# %% [markdown]
# ## 3) Carregar Dados

# %% [markdown]
# ### - Carregando

# %%
df = pd.read_csv(results_dataset_path.joinpath("summary", "dataset_anotado_completo.csv"))

print(f"Anotado: {len(df)}")
# Out:
# Anotado: 5000

# %% [markdown]
# ### - Dataset ground_truth

# %%
df_gt_train = (
    df[["text_id", "text", "ground_truth"]]
    .rename(columns={"ground_truth": "label"})
)

# %%
from src.utils.data_loader import add_label_description

df_gt_train = add_label_description(
    df_gt_train,
    dataset_name=DATASET_NAME
)

# %%
label_schema = LabelSchema.from_dataframe(df_gt_train)
print(label_schema.id2label)
# Out:
# {0: 'very negative sentiment', 1: 'negative sentiment', 2: 'neutral sentiment', 3: 'positive sentiment', 4: 'very positive sentiment'}

# %%
df_gt_train
# Out:
#       text_id                                               text  label  \
# 0           0  outside of burger 's desire to make some kind ...      1
# 1           1      ah-nuld 's action hero days might be over .\n      1
# 2           2  some people want the ol' ball-and-chain and th...      2
# 3           3  very amusing , not the usual route in a thrill...      3
# 4           4  be forewarned , if you 're depressed about any...      0
# ...       ...                                                ...    ...
# 4995     4995  must-see viewing for anyone involved in the hi...      4
# 4996     4996  there 's really only one good idea in this mov...      3
# 4997     4997  -lrb- kline 's -rrb- utterly convincing -- and...      4
# 4998     4998                  it is definitely worth seeing .\n      4
# 4999     4999  this dreadfully earnest inversion of the concu...      1
#
#             label_description
# 0          negative sentiment
# 1          negative sentiment
# 2           neutral sentiment
# 3          positive sentiment
# 4     very negative sentiment
# ...                       ...
# 4995  very positive sentiment
# 4996       positive sentiment
# 4997  very positive sentiment
# 4998  very positive sentiment
# 4999       negative sentiment
#
# [5000 rows x 4 columns]

# %% [markdown]
# ### - Dataset anotado

# %%
df_annotations = (
    df[["text_id", "text", "most_common_annotation"]]
    .rename(columns={"most_common_annotation": "label"})
)

# %%
df_annotations = add_label_description(
    df_annotations,
    dataset_name=DATASET_NAME
)

# %%
df_annotations
# Out:
#       text_id                                               text  label  \
# 0           0  outside of burger 's desire to make some kind ...      1
# 1           1      ah-nuld 's action hero days might be over .\n      1
# 2           2  some people want the ol' ball-and-chain and th...      1
# 3           3  very amusing , not the usual route in a thrill...      3
# 4           4  be forewarned , if you 're depressed about any...      0
# ...       ...                                                ...    ...
# 4995     4995  must-see viewing for anyone involved in the hi...      4
# 4996     4996  there 's really only one good idea in this mov...      3
# 4997     4997  -lrb- kline 's -rrb- utterly convincing -- and...      3
# 4998     4998                  it is definitely worth seeing .\n      3
# 4999     4999  this dreadfully earnest inversion of the concu...      0
#
#             label_description
# 0          negative sentiment
# 1          negative sentiment
# 2          negative sentiment
# 3          positive sentiment
# 4     very negative sentiment
# ...                       ...
# 4995  very positive sentiment
# 4996       positive sentiment
# 4997       positive sentiment
# 4998       positive sentiment
# 4999  very negative sentiment
#
# [5000 rows x 4 columns]

# %% [markdown]
# ### - Removendo instancias problemáticas e invalidas

# %% [markdown]
# #### -> Invalidas

# %%
df_invalid = df_annotations.loc[
    df_annotations["label"] == -1 
]

df_annotations = df_annotations[
        ~df_annotations["text_id"].isin(df_invalid["text_id"])
    ].reset_index(drop=True)

# %% [markdown]
# #### -> Problematicas

# %%
problematica_cases_path = results_dataset_path.joinpath("consensus", "problematic_cases.csv")
df_problematic = None

if problematica_cases_path.exists():
    df_problematic = pd.read_csv(problematica_cases_path)
    df_annotations = df_annotations[
        ~df_annotations["text_id"].isin(df_problematic["text_id"])
    ].reset_index(drop=True)

# %% [markdown]
# ### - Carrega dataset de teste e validação

# %%
df_eval, _ = load_hf_dataset_as_dataframe(
    dataset_name=DATASET_NAME,
    cache_dir=CACHE_DIR,
    dataset_global_config=DATASET_GLOBAL_CONFIG_EVAL,
)

print(f"Avaliação HF: {len(df_eval)}")
# Out:
# 12:13:08 | Carregando dataset: sst1
# 12:13:37 | Split 'test': 11855 exemplos
# 12:13:37 | Categorias extraídas automaticamente: [0, 1, 2, 3, 4]
# 12:13:37 | Amostra reduzida para 5000 exemplos (seed=42)
# 12:13:37 | Coluna de texto: text
# 12:13:37 | Ground truth carregado da coluna 'label'
# 12:13:37 | DataFrame criado com 5000 linhas
# Avaliação HF: 5000

# %%
from sklearn.model_selection import train_test_split

df_gt_val, df_gt_test = train_test_split(
    df_eval,
    test_size=0.5,
    random_state=42,
    stratify=df_eval["label"]
)

# %%
df_gt_val
# Out:
#                                                    text  label  \
# 173   cox is far more concerned with aggrandizing ma...      2
# 39    much of the lady and the duke is about quiet ,...      3
# 1099  victor rosa is leguizamo 's best movie work so...      4
# 4458  the year 's happiest surprise , a movie that d...      4
# 874   the irwins emerge unscathed , but the fictiona...      0
# ...                                                 ...    ...
# 1669          both deeply weird and charmingly dear .\n      3
# 4049  it 's a testament to de niro and director mich...      3
# 486   without the dark spookiness of crystal lake ca...      2
# 2561  everything is pegged into the groove of a new ...      2
# 2433  a captivating coming-of-age story that may als...      4
#
#             label_description
# 173         neutral sentiment
# 39         positive sentiment
# 1099  very positive sentiment
# 4458  very positive sentiment
# 874   very negative sentiment
# ...                       ...
# 1669       positive sentiment
# 4049       positive sentiment
# 486         neutral sentiment
# 2561        neutral sentiment
# 2433  very positive sentiment
#
# [2500 rows x 3 columns]

# %%
df_gt_test
# Out:
#                                                    text  label  \
# 24    not so much a movie as a picture book for the ...      1
# 3023  adolescents will be adequately served by the m...      3
# 1136  tsai ming-liang 's ghosts are painfully aware ...      2
# 4956  where tom green stages his gags as assaults on...      1
# 4571  the word that comes to mind , while watching e...      3
# ...                                                 ...    ...
# 1284  labute 's careful handling makes the material ...      4
# 4996  the town has kind of an authentic feel , but e...      1
# 2967  thanks to ice cube , benjamins feels an awful ...      2
# 235   i have a confession to make : i did n't partic...      1
# 2672  like being able to hit on a 15-year old when y...      1
#
#             label_description
# 24         negative sentiment
# 3023       positive sentiment
# 1136        neutral sentiment
# 4956       negative sentiment
# 4571       positive sentiment
# ...                       ...
# 1284  very positive sentiment
# 4996       negative sentiment
# 2967        neutral sentiment
# 235        negative sentiment
# 2672       negative sentiment
#
# [2500 rows x 3 columns]

# %% [markdown]
# ## 5) Converter para HuggingFace Dataset

# %%
from datasets import Dataset

train_gt = Dataset.from_pandas(df_gt_train)
train_consensus = Dataset.from_pandas(df_annotations)
test_dataset = Dataset.from_pandas(df_gt_test)
eval_dataset = Dataset.from_pandas(df_gt_val)

# %% [markdown]
# ## 6) Fine-tuning

# %%
model = "roberta-base"

# %%
fine_tune_output_dir = results_dataset_path.joinpath("finetuning")

Path.mkdir(fine_tune_output_dir, parents=True, exist_ok=True)

training_args = TrainingArguments(
    output_dir=fine_tune_output_dir,
    eval_strategy="epoch",
    save_strategy="epoch",

    learning_rate=5e-5,
    num_train_epochs=20,

    per_device_train_batch_size=16,   
    per_device_eval_batch_size=32,

    weight_decay=0.01,

    load_best_model_at_end=True,
    metric_for_best_model="f1_macro",
    greater_is_better=True,

    logging_strategy="epoch",
    save_total_limit=1,

    seed=42,
)

# %%
def run_fine_tuning(model, train_dataset, test_dataset, eval_dataset = None, experiment_name: str = "default"):
    fine_tuner = SupervisedFineTuner(
        model_name=model,
        training_args=training_args,
        label_schema=label_schema,
        tokenizer=HFTokenizer(
            model_name=model,
            max_length=256
        ),
        model_factory=ModelFactory,
        trainer_builder=TrainerBuilder,
        metrics_computer=MetricsComputer(),
    )

    fine_tuner.fit(train_dataset, eval_dataset)
    metrics = fine_tuner.evaluate(test_dataset)

    metrics["source"] = experiment_name

    return metrics

# %%
metrics_consensus = run_fine_tuning(
    model=model,
    train_dataset=train_consensus,
    test_dataset=test_dataset,
    eval_dataset=eval_dataset,
    experiment_name="consensus_llm",
)
# Out:
# Map:   0%|          | 0/4759 [00:00<?, ? examples/s]
# Map:   0%|          | 0/2500 [00:00<?, ? examples/s]
# Some weights of RobertaForSequenceClassification were not initialized from the model checkpoint at roberta-base and are newly initialized: ['classifier.dense.bias', 'classifier.dense.weight', 'classifier.out_proj.bias', 'classifier.out_proj.weight']
# You should probably TRAIN this model on a down-stream task to be able to use it for predictions and inference.
# The model is already on multiple devices. Skipping the move to device specified in `args`.
#     <div>
#
#       <progress value='5960' max='5960' style='width:300px; height:20px; vertical-align: middle;'></progress>
#       [5960/5960 1:55:41, Epoch 20/20]
#     </div>
#     <table border="1" class="dataframe">
#   <thead>
#  <tr style="text-align: left;">
#       <th>Epoch</th>
#       <th>Training Loss</th>
#       <th>Validation Loss</th>
#       <th>Accuracy</th>
#       <th>F1 Macro</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>1</td>
#       <td>1.105900</td>
#       <td>1.398207</td>
#       <td>0.504000</td>
#       <td>0.444775</td>
#     </tr>
#     <tr>
#       <td>2</td>
#       <td>0.690100</td>
#       <td>1.420022</td>
#       <td>0.528800</td>
#       <td>0.465631</td>
#     </tr>
#     <tr>
#       <td>3</td>
#       <td>0.467300</td>
#       <td>1.893673</td>
#       <td>0.517600</td>
#       <td>0.468923</td>
#     </tr>
#     <tr>
#       <td>4</td>
#       <td>0.337500</td>
#       <td>2.270445</td>
#       <td>0.511600</td>
#       <td>0.473746</td>
#     </tr>
#     <tr>
#       <td>5</td>
#       <td>0.275100</td>
#       <td>2.553412</td>
#       <td>0.516800</td>
#       <td>0.478812</td>
#     </tr>
#     <tr>
#       <td>6</td>
#       <td>0.242100</td>
#       <td>2.675191</td>
#       <td>0.514800</td>
#       <td>0.479261</td>
#     </tr>
#     <tr>
#       <td>7</td>
#       <td>0.194800</td>
#       <td>2.905518</td>
#       <td>0.527200</td>
#       <td>0.492192</td>
#     </tr>
#     <tr>
#       <td>8</td>
#       <td>0.160300</td>
#       <td>2.957918</td>
#       <td>0.521600</td>
#       <td>0.479263</td>
#     </tr>
#     <tr>
#       <td>9</td>
#       <td>0.154000</td>
#       <td>3.211463</td>
#       <td>0.513600</td>
#       <td>0.460135</td>
#     </tr>
#     <tr>
#       <td>10</td>
#       <td>0.141900</td>
#       <td>3.280273</td>
#       <td>0.511200</td>
#       <td>0.472781</td>
#     </tr>
#     <tr>
#       <td>11</td>
#       <td>0.116300</td>
#       <td>3.025052</td>
#       <td>0.533200</td>
#       <td>0.491574</td>
#     </tr>
#     <tr>
#       <td>12</td>
#       <td>0.101200</td>
#       <td>3.409505</td>
#       <td>0.530000</td>
#       <td>0.478855</td>
#     </tr>
#     <tr>
#       <td>13</td>
#       <td>0.085900</td>
#       <td>3.516402</td>
#       <td>0.524400</td>
#       <td>0.479660</td>
#     </tr>
#     <tr>
#       <td>14</td>
#       <td>0.075400</td>
#       <td>3.709788</td>
#       <td>0.530000</td>
#       <td>0.473552</td>
#     </tr>
#     <tr>
#       <td>15</td>
#       <td>0.062800</td>
#       <td>3.618881</td>
#       <td>0.526800</td>
#       <td>0.473424</td>
#     </tr>
#     <tr>
#       <td>16</td>
#       <td>0.047900</td>
#       <td>3.863434</td>
#       <td>0.520000</td>
#       <td>0.462305</td>
#     </tr>
#     <tr>
#       <td>17</td>
#       <td>0.045800</td>
#       <td>3.656159</td>
#       <td>0.525200</td>
#       <td>0.480610</td>
#     </tr>
#     <tr>
#       <td>18</td>
#       <td>0.035100</td>
#       <td>3.925823</td>
#       <td>0.531600</td>
#       <td>0.477342</td>
#     </tr>
#     <tr>
#       <td>19</td>
#       <td>0.034000</td>
#       <td>3.959964</td>
#       <td>0.530000</td>
#       <td>0.476550</td>
#     </tr>
#     <tr>
#       <td>20</td>
#       <td>0.028400</td>
#       <td>3.988268</td>
#       <td>0.527600</td>
#       <td>0.475852</td>
#     </tr>
#   </tbody>
# </table><p>
# Map:   0%|          | 0/2500 [00:00<?, ? examples/s]
#     <div>
#
#       <progress value='79' max='79' style='width:300px; height:20px; vertical-align: middle;'></progress>
#       [79/79 00:43]
#     </div>

# %%
metrics_gt = run_fine_tuning(
    model=model,
    train_dataset=train_gt,
    test_dataset=test_dataset,
    eval_dataset=eval_dataset,
    experiment_name="ground_truth",
)
# Out:
# Map:   0%|          | 0/5000 [00:00<?, ? examples/s]
# Map:   0%|          | 0/2500 [00:00<?, ? examples/s]
# Some weights of RobertaForSequenceClassification were not initialized from the model checkpoint at roberta-base and are newly initialized: ['classifier.dense.bias', 'classifier.dense.weight', 'classifier.out_proj.bias', 'classifier.out_proj.weight']
# You should probably TRAIN this model on a down-stream task to be able to use it for predictions and inference.
# The model is already on multiple devices. Skipping the move to device specified in `args`.
#     <div>
#
#       <progress value='6260' max='6260' style='width:300px; height:20px; vertical-align: middle;'></progress>
#       [6260/6260 1:24:28, Epoch 20/20]
#     </div>
#     <table border="1" class="dataframe">
#   <thead>
#  <tr style="text-align: left;">
#       <th>Epoch</th>
#       <th>Training Loss</th>
#       <th>Validation Loss</th>
#       <th>Accuracy</th>
#       <th>F1 Macro</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>1</td>
#       <td>1.354300</td>
#       <td>1.217204</td>
#       <td>0.455600</td>
#       <td>0.367447</td>
#     </tr>
#     <tr>
#       <td>2</td>
#       <td>1.017300</td>
#       <td>1.088655</td>
#       <td>0.576800</td>
#       <td>0.554859</td>
#     </tr>
#     <tr>
#       <td>3</td>
#       <td>0.806300</td>
#       <td>0.999335</td>
#       <td>0.618800</td>
#       <td>0.602298</td>
#     </tr>
#     <tr>
#       <td>4</td>
#       <td>0.577800</td>
#       <td>1.076898</td>
#       <td>0.638400</td>
#       <td>0.625499</td>
#     </tr>
#     <tr>
#       <td>5</td>
#       <td>0.420400</td>
#       <td>1.151666</td>
#       <td>0.638000</td>
#       <td>0.632655</td>
#     </tr>
#     <tr>
#       <td>6</td>
#       <td>0.299300</td>
#       <td>1.445358</td>
#       <td>0.632800</td>
#       <td>0.625578</td>
#     </tr>
#     <tr>
#       <td>7</td>
#       <td>0.274100</td>
#       <td>1.572421</td>
#       <td>0.663600</td>
#       <td>0.657928</td>
#     </tr>
#     <tr>
#       <td>8</td>
#       <td>0.217400</td>
#       <td>1.777372</td>
#       <td>0.672400</td>
#       <td>0.668399</td>
#     </tr>
#     <tr>
#       <td>9</td>
#       <td>0.150200</td>
#       <td>2.138284</td>
#       <td>0.661600</td>
#       <td>0.651067</td>
#     </tr>
#     <tr>
#       <td>10</td>
#       <td>0.148300</td>
#       <td>2.183770</td>
#       <td>0.673200</td>
#       <td>0.668647</td>
#     </tr>
#     <tr>
#       <td>11</td>
#       <td>0.108700</td>
#       <td>2.327429</td>
#       <td>0.662800</td>
#       <td>0.654448</td>
#     </tr>
#     <tr>
#       <td>12</td>
#       <td>0.089300</td>
#       <td>2.433417</td>
#       <td>0.665600</td>
#       <td>0.661253</td>
#     </tr>
#     <tr>
#       <td>13</td>
#       <td>0.042800</td>
#       <td>2.572056</td>
#       <td>0.690400</td>
#       <td>0.678550</td>
#     </tr>
#     <tr>
#       <td>14</td>
#       <td>0.052600</td>
#       <td>2.793589</td>
#       <td>0.676400</td>
#       <td>0.672385</td>
#     </tr>
#     <tr>
#       <td>15</td>
#       <td>0.037400</td>
#       <td>2.784568</td>
#       <td>0.686000</td>
#       <td>0.679198</td>
#     </tr>
#     <tr>
#       <td>16</td>
#       <td>0.035400</td>
#       <td>2.816971</td>
#       <td>0.685600</td>
#       <td>0.677382</td>
#     </tr>
#     <tr>
#       <td>17</td>
#       <td>0.025700</td>
#       <td>2.807340</td>
#       <td>0.692400</td>
#       <td>0.684260</td>
#     </tr>
#     <tr>
#       <td>18</td>
#       <td>0.013800</td>
#       <td>2.827309</td>
#       <td>0.691200</td>
#       <td>0.684019</td>
#     </tr>
#     <tr>
#       <td>19</td>
#       <td>0.012300</td>
#       <td>2.848875</td>
#       <td>0.694000</td>
#       <td>0.685201</td>
#     </tr>
#     <tr>
#       <td>20</td>
#       <td>0.006800</td>
#       <td>2.885934</td>
#       <td>0.692400</td>
#       <td>0.683579</td>
#     </tr>
#   </tbody>
# </table><p>
# Map:   0%|          | 0/2500 [00:00<?, ? examples/s]
#     <div>
#
#       <progress value='79' max='79' style='width:300px; height:20px; vertical-align: middle;'></progress>
#       [79/79 00:20]
#     </div>

# %%
results = pd.DataFrame([metrics_consensus, metrics_gt])
results
# Out:
#    eval_loss  eval_accuracy  eval_f1_macro  eval_runtime  \
# 0   3.048118         0.5096       0.472486       44.2883
# 1   2.928392         0.6812       0.674524       20.5520
#
#    eval_samples_per_second  eval_steps_per_second  epoch         source
# 0                   56.448                  1.784   20.0  consensus_llm
# 1                  121.643                  3.844   20.0   ground_truth

# %%
results.to_csv(fine_tune_output_dir.joinpath(f"{model}_fine_tuning_results.csv"), index=False)
